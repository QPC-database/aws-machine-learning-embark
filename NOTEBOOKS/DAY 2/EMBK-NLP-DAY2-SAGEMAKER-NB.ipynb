# %% [markdown]
# ### Sagemaker built-in Training and Deployment with LinearLearner
#
# In this notebook, we use Sagemaker's built-in machine learning __LinearLearner__ model to predict the __log_votes__ field of our review dataset.
#
# * Find more details on the Sagemaker's __LinearLearner__ here: https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html
#
# Overall dataset schema:
# * __reviewText:__ Text of the review
# * __summary:__ Summary of the review
# * __verified:__ Whether the purchase was verified (True or False)
# * __time:__ UNIX timestamp for the review
# * __rating:__ Rating of the review
# * __log_votes:__ Logarithm-adjusted votes log(1+votes)

# %% [markdown]
# ### 1. Reading the dataset
#
# We will use the __pandas__ library to read our dataset.

# %%
import pandas as pd
from sklearn.utils import shuffle

df = pd.read_csv('../../DATA/NLP/EMBK-NLP-REVIEW-DATA-CSV.csv')

print('The shape of the dataset is:', df.shape)
# Out:
# The shape of the dataset is: (55000, 6)

# %% [markdown]
# Let's look at the first five rows in the dataset. As you can see the __log_votes__ field is numeric. That's why we will build a regression model.

# %%
df.head()
# Out:
#                                           reviewText  \
# 0  Stuck with this at work, slow and we still got...
# 1  I use parallels every day with both my persona...
# 2  Barbara Robbins\n\nI've used TurboTax to do ou...
# 3  I have been using this software security for y...
# 4  If you want your computer hijacked and slowed ...
#
#                                              summary  verified        time  \
# 0                                  Use SEP or Mcafee     False  1464739200
# 1                                       Use it daily     False  1332892800
# 2                                    Helpful Product      True  1398816000
# 3                                         Five Stars      True  1430784000
# 4  ... hijacked and slowed to a crawl Windows 10 ...     False  1508025600
#
#    rating  log_votes
# 0     1.0        0.0
# 1     5.0        0.0
# 2     4.0        0.0
# 3     5.0        0.0
# 4     1.0        0.0

# %% [markdown]
# ### 2. Exploratory Data Analysis and Missing Value Imputation

# %% [markdown]
# Let's look at the range and distribution of log_votes

# %%
df["log_votes"].min()
# Out:
# 0.0

# %%
df["log_votes"].max()
# Out:
# 7.799753318287247

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df["log_votes"].plot.hist()
plt.show()

# %% [markdown]
# We can check the number of missing values for each columm below.

# %%
print(df.isna().sum())
# Out:
# reviewText    6
# summary       7
# verified      0
# time          0
# rating        0
# log_votes     0
# dtype: int64

# %% [markdown]
# Let's fill-in the missing values for reviewText below. We will just use the placeholder "Missing" here.

# %%
df["reviewText"].fillna("Missing", inplace=True)

# %% [markdown]
# ### 3. Stop Word Removal and Stemming

# %%
# Install the library and functions
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# We will create the stop word removal and text cleaning processes below. NLTK library provides a list of common stop words. We will use the list, but remove some of the words from that list. It is because those words are actually useful to understand the sentiment in the sentence.

# %%
import nltk, re
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

# Let's get a list of stop words from the NLTK library
stop = stopwords.words('english')

# These words are important for our problem. We don't want to remove them.
excluding = ['against', 'not', 'don', "don't",'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't",
             'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 
             'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't",'shouldn', "shouldn't", 'wasn',
            "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# New stop word list
stop_words = [word for word in stop if word not in excluding]

snow = SnowballStemmer('english')

def process_text(texts): 
    final_text_list=[]
    for sent in texts:
        filtered_sentence=[]
        
        sent = sent.lower() # Lowercase 
        sent = sent.strip() # Remove leading/trailing whitespace
        sent = re.sub('\s+', ' ', sent) # Remove extra space and tabs
        sent = re.compile('<.*?>').sub('', sent) # Remove HTML tags/markups:
        
        for w in word_tokenize(sent):
            # We are applying some custom filtering here, feel free to try different things
            # Check if it is not numeric and its length>2 and not in stop words
            if(not w.isnumeric()) and (len(w)>2) and (w not in stop_words):  
                # Stem and add to filtered list
                filtered_sentence.append(snow.stem(w))
        final_string = " ".join(filtered_sentence) #final string of cleaned words
 
        final_text_list.append(final_string)
    
    return final_text_list

# %%
print("Pre-processing the reviewText field")
df["reviewText"] = process_text(df["reviewText"].tolist())
# Out:
# Pre-processing the reviewText field

# %% [markdown]
# ### 4. Scaling numerical fields:
#
# We will apply min-max scaling to our rating field so that they will be between 0-1.

# %%
df["rating"] = (df["rating"] - df["rating"].min())/ (df["rating"].max()-df["rating"].min())
df["time"] = (df["time"] - df["time"].min())/ (df["time"].max()-df["time"].min())

# %% [markdown]
# ### 5. Splitting the training dataset into training, validation and test
#
# Sklearn library has a useful function to split datasets. We will use the __train_test_split()__ function. In the example below, we get 80% for training, 10% for validation and 10% for test.

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(df[["reviewText", "rating", "time"]], # Using these three fields
                                                  df["log_votes"].tolist(),             # Target field
                                                  test_size=0.20,                       # 20% -> test+validation
                                                  shuffle=True                          # Shuffle the whole dataset
                                                 )

X_test, X_val, y_test, y_val = train_test_split(X_val,
                                                y_val,
                                                test_size=0.50,  # 10% test and 10%val
                                                shuffle=True     # Shuffle the whole dataset
                                               )

# %% [markdown]
# ### 6. Computing Bag of Words Features
#
# We are using binary features here. TF and TF-IDF are also other options.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the binary count vectorizer
tfidf_vectorizer = CountVectorizer(binary=True,
                                   max_features=50    # Limit the vocabulary size
                                  )

X_train_text_vectors = tfidf_vectorizer.fit_transform(X_train["reviewText"].tolist())  # Fit and transform
X_val_text_vectors = tfidf_vectorizer.transform(X_val["reviewText"].tolist())          # Only transform
X_test_text_vectors = tfidf_vectorizer.transform(X_test["reviewText"].tolist())        # Only transform

# %% [markdown]
# Let's print our vocabulary below. The number next to the word is its index in the vocabulary.

# %%
tfidf_vectorizer.vocabulary_
# Out:
# {'time': 36,
#  'great': 13,
#  'product': 27,
#  'price': 25,
#  'could': 5,
#  'use': 39,
#  'work': 47,
#  'well': 45,
#  'buy': 3,
#  'back': 1,
#  'upgrad': 38,
#  'year': 49,
#  'would': 48,
#  'run': 32,
#  'softwar': 33,
#  'not': 23,
#  'get': 11,
#  'tri': 37,
#  'version': 42,
#  'new': 22,
#  'make': 18,
#  'also': 0,
#  'easi': 7,
#  'better': 2,
#  'need': 21,
#  'file': 9,
#  'like': 16,
#  'help': 14,
#  'realli': 30,
#  'much': 20,
#  've': 41,
#  'good': 12,
#  'mani': 19,
#  'recommend': 31,
#  'one': 24,
#  'download': 6,
#  'program': 28,
#  'want': 43,
#  'way': 44,
#  'still': 34,
#  'look': 17,
#  'even': 8,
#  'comput': 4,
#  'instal': 15,
#  'window': 46,
#  'find': 10,
#  'problem': 26,
#  'purchas': 29,
#  'support': 35,
#  'user': 40}

# %% [markdown]
# ### 7. Training with Sagemaker

# %% [markdown]
# We will call the Sagemaker `LinearLearner()` below.
# * __Compute power:__ We will use `train_instance_count` and `train_instance_type` parameters. This example uses `ml.m4.4xlarge` resource for training. We can change the instance type for our needs (For example GPUs for neural networks).
# * __Model type:__ `predictor_type` is set to __'regressor'__ as we have a regression problem. For classification, we can choose between `binary_classifier` and `multiclass_classifier`.

# %%
import sagemaker

# Call the LinearLearner estimator object
linear_regressor = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               train_instance_count=1,
                                               train_instance_type='ml.m4.4xlarge',
                                               predictor_type='regressor')

# %% [markdown]
# We are using the `record_set()` function of our binary_estimator to set the training, validation, test parts of the estimator.

# %%
import numpy as np

# Let' merge our training features
train_features = np.column_stack((X_train_text_vectors.toarray(), 
                                    X_train["rating"].values, 
                                    X_train["time"].values)
                                  ).astype("float32")
# Let' merge our val features
val_features = np.column_stack((X_val_text_vectors.toarray(), 
                                    X_val["rating"].values, 
                                    X_val["time"].values)
                                  ).astype("float32")
# Let' merge our test features
test_features = np.column_stack((X_test_text_vectors.toarray(), 
                                    X_test["rating"].values, 
                                    X_test["time"].values)
                                  ).astype("float32")

train_records = linear_regressor.record_set(train_features, np.array(y_train).astype("float32"), channel='train')
val_records = linear_regressor.record_set(val_features, np.array(y_val).astype("float32"), channel='validation')
test_records = linear_regressor.record_set(test_features, np.array(y_test).astype("float32"), channel='test')

# %% [markdown]
# `fit()` function applies a distributed version of the Stochastic Gradient Descent (SGD) algorithm and we are sending the data to it.

# %%
linear_regressor.fit([train_records, val_records, test_records])
# Out:
# 2020-02-12 03:08:13 Starting - Starting the training job...
# 2020-02-12 03:08:15 Starting - Launching requested ML instances.........
# 2020-02-12 03:09:45 Starting - Preparing the instances for training...
# 2020-02-12 03:10:34 Downloading - Downloading input data...
# 2020-02-12 03:11:04 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [02/12/2020 03:11:20 INFO 140385570637632] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/12/2020 03:11:20 INFO 140385570637632] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'52', u'mini_batch_size': u'1000', u'predictor_type': u'regressor'}
# [02/12/2020 03:11:20 INFO 140385570637632] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'52', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/12/2020 03:11:20 WARNING 140385570637632] Loggers have already been setup.
# Process 1 is a worker.
# [02/12/2020 03:11:20 INFO 140385570637632] Using default worker.
# [2020-02-12 03:11:20.588] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-02-12 03:11:20.592] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-02-12 03:11:20.615] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1, "num_bytes": 256000}
# [02/12/2020 03:11:20 INFO 140385570637632] Create Store: local
# [2020-02-12 03:11:20.662] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 47, "num_examples": 11, "num_bytes": 2816000}
# [02/12/2020 03:11:20 INFO 140385570637632] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fadc1a354d0>
# [02/12/2020 03:11:20 INFO 140385570637632] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.29669908 0.28049824 0.26630273 0.3096903  0.35491967 0.30725497
#  0.30725494 0.34442228 0.3062017  0.27574477 0.27491793 0.39793998
#  0.35519007 0.371999   0.28552946 0.3504433  0.37816864 0.26426944
#  0.32011586 0.28156844 0.29805076 0.35219246 0.31759033 0.47989377
#  0.3683674  0.2721358  0.32346734 0.42496082 0.3899845  0.30192968
#  0.2753318  0.27464154 0.27861091 0.41619784 0.265434   0.28063238
#  0.38606912 0.33700222 0.2705882  0.4886151  0.2830303  0.28670204
#  0.3649114  0.30865037 0.2835591  0.30888197 0.3142447  0.44953176
#  0.37571266 0.40034053 0.4084697  0.19471893]
# <NDArray 52 @cpu(0)>, 'stdev_label':
# [0.96518964]
# <NDArray 1 @cpu(0)>, 'mean_label':
#

#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.909779052734375, "sum": 0.909779052734375, "min": 0.909779052734375}}, "EndTime": 1581477085.923741, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923731}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9095837069424716, "sum": 0.9095837069424716, "min": 0.9095837069424716}}, "EndTime": 1581477085.923772, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923764}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9095626886541193, "sum": 0.9095626886541193, "min": 0.9095626886541193}}, "EndTime": 1581477085.923802, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923794}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9102245427911931, "sum": 0.9102245427911931, "min": 0.9102245427911931}}, "EndTime": 1581477085.92384, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923831}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9126590021306819, "sum": 0.9126590021306819, "min": 0.9126590021306819}}, "EndTime": 1581477085.923887, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923871}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9092921808416193, "sum": 0.9092921808416193, "min": 0.9092921808416193}}, "EndTime": 1581477085.923926, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923917}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 0.9138314763849432, "sum": 0.9138314763849432, "min": 0.9138314763849432}}, "EndTime": 1581477085.923957, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.923949}
#
# [02/12/2020 03:11:25 INFO 140385570637632] #quality_metric: host=algo-1, epoch=5, validation mse_objective <loss>=0.629887656472
# [02/12/2020 03:11:25 INFO 140385570637632] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=mse_objective, value=0.629378451261
# [02/12/2020 03:11:25 INFO 140385570637632] Early stop condition met. Stopping training.
# [02/12/2020 03:11:25 INFO 140385570637632] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Number of Batches Since Last Reset": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Number of Records Since Last Reset": {"count": 1, "max": 44000, "sum": 44000.0, "min": 44000}, "Total Batches Seen": {"count": 1, "max": 276, "sum": 276.0, "min": 276}, "Total Records Seen": {"count": 1, "max": 276000, "sum": 276000.0, "min": 276000}, "Max Records Seen Between Resets": {"count": 1, "max": 44000, "sum": 44000.0, "min": 44000}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1581477085.924781, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1581477085.141424}
#
# [02/12/2020 03:11:25 INFO 140385570637632] #throughput_metric: host=algo-1, train throughput=56161.1213395 records/second
# [02/12/2020 03:11:25 WARNING 140385570637632] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/12/2020 03:11:25 WARNING 140385570637632] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-02-12 03:11:26.000] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 20, "duration": 55, "num_examples": 6, "num_bytes": 1408000}
# [02/12/2020 03:11:26 INFO 140385570637632] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=mse_objective, value=0.629378451261
# [2020-02-12 03:11:26.026] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 22, "duration": 17, "num_examples": 6, "num_bytes": 1408000}
# [02/12/2020 03:11:26 INFO 140385570637632] #validation_score (algo-1) : ('mse_objective', 0.6294520485617898)
# [02/12/2020 03:11:26 INFO 140385570637632] #validation_score (algo-1) : ('mse', 0.6294520485617898)
# [02/12/2020 03:11:26 INFO 140385570637632] #validation_score (algo-1) : ('absolute_loss', 0.5501445645419034)
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, validation mse_objective <loss>=0.629452048562
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, validation mse <loss>=0.629452048562
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, validation absolute_loss <loss>=0.550144564542
# [02/12/2020 03:11:26 INFO 140385570637632] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.01, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [02/12/2020 03:11:26 INFO 140385570637632] Saved checkpoint to "/tmp/tmpUvV92D/mx-mod-0000.params"
# [2020-02-12 03:11:26.031] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 5439, "num_examples": 1, "num_bytes": 256000}
# [2020-02-12 03:11:26.050] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 18, "num_examples": 6, "num_bytes": 1408000}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Records Since Last Reset": {"count": 1, "max": 5500, "sum": 5500.0, "min": 5500}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 5500, "sum": 5500.0, "min": 5500}, "Max Records Seen Between Resets": {"count": 1, "max": 5500, "sum": 5500.0, "min": 5500}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1581477086.050411, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581477086.03186}
#
# [02/12/2020 03:11:26 INFO 140385570637632] #test_score (algo-1) : ('mse_objective', 0.5872292646928267)
# [02/12/2020 03:11:26 INFO 140385570637632] #test_score (algo-1) : ('mse', 0.5872292646928267)
# [02/12/2020 03:11:26 INFO 140385570637632] #test_score (algo-1) : ('absolute_loss', 0.5340168290571733)
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, test mse_objective <loss>=0.587229264693
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, test mse <loss>=0.587229264693
# [02/12/2020 03:11:26 INFO 140385570637632] #quality_metric: host=algo-1, test absolute_loss <loss>=0.534016829057
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 5684.929132461548, "sum": 5684.929132461548, "min": 5684.929132461548}, "finalize.time": {"count": 1, "max": 102.39791870117188, "sum": 102.39791870117188, "min": 102.39791870117188}, "initialize.time": {"count": 1, "max": 169.0821647644043, "sum": 169.0821647644043, "min": 169.0821647644043}, "check_early_stopping.time": {"count": 7, "max": 1.3921260833740234, "sum": 3.4990310668945312, "min": 0.17595291137695312}, "setuptime": {"count": 1, "max": 29.90102767944336, "sum": 29.90102767944336, "min": 29.90102767944336}, "update.time": {"count": 6, "max": 950.1678943634033, "sum": 5156.617879867554, "min": 783.1270694732666}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1581477086.053943, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1581477080.584436}
#
#
# 2020-02-12 03:11:34 Uploading - Uploading generated training model
# 2020-02-12 03:11:34 Completed - Training job completed
# Training seconds: 60
# Billable seconds: 60

# %% [markdown]
# ### 8. Model Evaluation
#
# In this section, we will look at how our model performs with our test dataset.

# %% [markdown]
# ### Sagemaker Analytics
# We can use Sagemaker analytics to get some performance metrics of our choice. This doesn't require us to deploy our model. Since this is a regression problem, we can check the mean squared error and absolute loss.

# %%
sagemaker.analytics.TrainingJobAnalytics(linear_regressor._current_job_name, 
                                         metric_names = ['test:mse', 'test:absolute_loss']
                                        ).dataframe()
# Out:
#    timestamp         metric_name     value
# 0        0.0            test:mse  0.587229
# 1        0.0  test:absolute_loss  0.534017

# %% [markdown]
# ### 9. Deploying the model and using the endpoint
#
# In the last part of this exercise, we will deploy our model to another instance of our choice. This will allow us to use this model in production systems. Deployed endpoints can be used with other AWS Services such as Lambda and API Gateway. A nice walkthrough is available here: https://aws.amazon.com/blogs/machine-learning/call-an-amazon-sagemaker-model-endpoint-using-amazon-api-gateway-and-aws-lambda/ if you are interested.
#
# __9.1 Deploy the model:__
#
# Run the following cell to deploy the model. We are using this instance type: `ml.m4.4xlarge` This will take some time to complete.

# %%
linear_regressor_predictor = linear_regressor.deploy(initial_instance_count = 1,
